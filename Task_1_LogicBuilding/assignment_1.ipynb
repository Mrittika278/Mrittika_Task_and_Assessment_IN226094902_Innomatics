# %%
username = "selvi"  #hardcoded details
password = "2000"

input_username = input("Enter username: ")    #getting input from the user
input_password = input("Enter password: ")


if input_username == username and input_password == password: #Validating using if loop
    print("Login Successful")
else:
    print("Invalid Credentials,Please Try again")
# Out:
# Enter username:  selvi
# Enter password:  2030
# Invalid Credentials,Please Try again

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Students:", len(marks))
print("Passed Students:", pass_count)
print("Failed Students:", fail_count)
# Out:
# Total Students: 5
# Passed Students: 3
# Failed Students: 2

# %%
names = [" Rahul ", "preethi", " VIJAY "]

cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)

print("Cleaned Names:", cleaned_names)
# Out:
# Cleaned Names: ['rahul', 'preethi', 'vijay']

# %%
messages = ["Hi", "Welcome to innomatics ", "OK"]

for message in messages:
    length = len(message)
    print(f"Message: '{message}' | Length: {length}")
    
    if length > 10:
        print("-> This message is longer than 10 characters.")
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to innomatics ' | Length: 22
# -> This message is longer than 10 characters.
# Message: 'OK' | Length: 2

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("Total ERROR messages:", error_count)
# Out:
# Total ERROR messages: 2
